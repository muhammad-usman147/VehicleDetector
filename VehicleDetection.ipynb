# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#reading the images
plt.figure(figsize=(12,8))
img = cv2.imread('2.PNG')
plt.imshow(img[:,:,::-1]);

# %%
#drawing Canny images
plt.figure(figsize=(12,8))
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
#find canny edges
plt.figure(figsize=(12,8))
edged = cv2.Canny(gray,50,200)
plt.imshow(edged)

# %%
#find canny edges
plt.figure(figsize=(12,8))
edged = cv2.Canny(gray,1,200)
plt.imshow(edged)

# %%
#finding contours 
plt.figure(figsize=(12,8))
contours, _ = cv2.findContours(edged,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
cv2.drawContours(img,contours,-1,(0,255,0),3)
plt.imshow(img)

# %%
_
# Out:
# array([[[  1,  -1,  -1,  -1],
#         [  2,   0,  -1,  -1],
#         [  3,   1,  -1,  -1],
#         [  4,   2,  -1,  -1],
#         [  5,   3,  -1,  -1],
#         [  6,   4,  -1,  -1],
#         [  7,   5,  -1,  -1],
#         [  8,   6,  -1,  -1],
#         [  9,   7,  -1,  -1],
#         [ 10,   8,  -1,  -1],
#         [ 11,   9,  -1,  -1],
#         [ 12,  10,  -1,  -1],
#         [ 13,  11,  -1,  -1],
#         [ 14,  12,  -1,  -1],
#         [ 15,  13,  -1,  -1],
#         [ 16,  14,  -1,  -1],
#         [ 17,  15,  -1,  -1],
#         [ 18,  16,  -1,  -1],
#         [ 19,  17,  -1,  -1],
#         [ 20,  18,  -1,  -1],
#         [ 21,  19,  -1,  -1],
#         [ 22,  20,  -1,  -1],
#         [ 23,  21,  -1,  -1],
#         [ 24,  22,  -1,  -1],
#         [ 25,  23,  -1,  -1],
#         [ 26,  24,  -1,  -1],
#         [ 27,  25,  -1,  -1],
#         [ 28,  26,  -1,  -1],
#         [ 29,  27,  -1,  -1],
#         [ 30,  28,  -1,  -1],
#         [ 31,  29,  -1,  -1],
#         [ 32,  30,  -1,  -1],
#         [ 33,  31,  -1,  -1],
#         [ 34,  32,  -1,  -1],
#         [ 35,  33,  -1,  -1],
#         [ 36,  34,  -1,  -1],
#         [ 37,  35,  -1,  -1],
#         [ 38,  36,  -1,  -1],
#         [ 39,  37,  -1,  -1],
#         [ 40,  38,  -1,  -1],
#         [ 41,  39,  -1,  -1],
#         [ 42,  40,  -1,  -1],
#         [ 43,  41,  -1,  -1],
#         [ 44,  42,  -1,  -1],
#         [ 45,  43,  -1,  -1],
#         [ 46,  44,  -1,  -1],
#         [ 47,  45,  -1,  -1],
#         [ 48,  46,  -1,  -1],
#         [ 49,  47,  -1,  -1],
#         [ 50,  48,  -1,  -1],
#         [ 51,  49,  -1,  -1],
#         [ 52,  50,  -1,  -1],
#         [ 53,  51,  -1,  -1],
#         [ 54,  52,  -1,  -1],
#         [ 55,  53,  -1,  -1],
#         [ 56,  54,  -1,  -1],
#         [ 57,  55,  -1,  -1],
#         [ 58,  56,  -1,  -1],
#         [ 59,  57,  -1,  -1],
#         [ 60,  58,  -1,  -1],
#         [ 61,  59,  -1,  -1],
#         [ 62,  60,  -1,  -1],
#         [ 63,  61,  -1,  -1],
#         [ 64,  62,  -1,  -1],
#         [ 65,  63,  -1,  -1],
#         [ 66,  64,  -1,  -1],
#         [ 67,  65,  -1,  -1],
#         [ 68,  66,  -1,  -1],
#         [ 69,  67,  -1,  -1],
#         [ 70,  68,  -1,  -1],
#         [ 71,  69,  -1,  -1],
#         [ 72,  70,  -1,  -1],
#         [ 73,  71,  -1,  -1],
#         [ 74,  72,  -1,  -1],
#         [ 75,  73,  -1,  -1],
#         [ 76,  74,  -1,  -1],
#         [ 77,  75,  -1,  -1],
#         [ 78,  76,  -1,  -1],
#         [ 79,  77,  -1,  -1],
#         [ 80,  78,  -1,  -1],
#         [ 81,  79,  -1,  -1],
#         [ 82,  80,  -1,  -1],
#         [ 83,  81,  -1,  -1],
#         [ 84,  82,  -1,  -1],
#         [ 85,  83,  -1,  -1],
#         [ 86,  84,  -1,  -1],
#         [ 87,  85,  -1,  -1],
#         [ 88,  86,  -1,  -1],
#         [ 89,  87,  -1,  -1],
#         [ 90,  88,  -1,  -1],
#         [ 91,  89,  -1,  -1],
#         [ 92,  90,  -1,  -1],
#         [ 93,  91,  -1,  -1],
#         [ 94,  92,  -1,  -1],
#         [ 95,  93,  -1,  -1],
#         [ 96,  94,  -1,  -1],
#         [ 97,  95,  -1,  -1],
#         [ 98,  96,  -1,  -1],
#         [ 99,  97,  -1,  -1],
#         [100,  98,  -1,  -1],
#         [101,  99,  -1,  -1],
#         [102, 100,  -1,  -1],
#         [103, 101,  -1,  -1],
#         [104, 102,  -1,  -1],
#         [105, 103,  -1,  -1],
#         [106, 104,  -1,  -1],
#         [107, 105,  -1,  -1],
#         [108, 106,  -1,  -1],
#         [109, 107,  -1,  -1],
#         [110, 108,  -1,  -1],
#         [111, 109,  -1,  -1],
#         [112, 110,  -1,  -1],
#         [113, 111,  -1,  -1],
#         [114, 112,  -1,  -1],
#         [115, 113,  -1,  -1],
#         [116, 114,  -1,  -1],
#         [117, 115,  -1,  -1],
#         [118, 116,  -1,  -1],
#         [119, 117,  -1,  -1],
#         [120, 118,  -1,  -1],
#         [121, 119,  -1,  -1],
#         [122, 120,  -1,  -1],
#         [123, 121,  -1,  -1],
#         [124, 122,  -1,  -1],
#         [125, 123,  -1,  -1],
#         [126, 124,  -1,  -1],
#         [127, 125,  -1,  -1],
#         [128, 126,  -1,  -1],
#         [129, 127,  -1,  -1],
#         [130, 128,  -1,  -1],
#         [131, 129,  -1,  -1],
#         [132, 130,  -1,  -1],
#         [133, 131,  -1,  -1],
#         [134, 132,  -1,  -1],
#         [135, 133,  -1,  -1],
#         [136, 134,  -1,  -1],
#         [137, 135,  -1,  -1],
#         [138, 136,  -1,  -1],
#         [139, 137,  -1,  -1],
#         [140, 138,  -1,  -1],
#         [141, 139,  -1,  -1],
#         [142, 140,  -1,  -1],
#         [143, 141,  -1,  -1],
#         [144, 142,  -1,  -1],
#         [145, 143,  -1,  -1],
#         [146, 144,  -1,  -1],
#         [147, 145,  -1,  -1],
#         [148, 146,  -1,  -1],
#         [149, 147,  -1,  -1],
#         [150, 148,  -1,  -1],
#         [151, 149,  -1,  -1],
#         [152, 150,  -1,  -1],
#         [153, 151,  -1,  -1],
#         [154, 152,  -1,  -1],
#         [155, 153,  -1,  -1],
#         [156, 154,  -1,  -1],
#         [157, 155,  -1,  -1],
#         [158, 156,  -1,  -1],
#         [159, 157,  -1,  -1],
#         [160, 158,  -1,  -1],
#         [161, 159,  -1,  -1],
#         [162, 160,  -1,  -1],
#         [163, 161,  -1,  -1],
#         [ -1, 162,  -1,  -1]]], dtype=int32)
